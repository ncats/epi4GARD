# %%
from datasets import load_dataset

# %%
dataset = load_dataset("ncats/EpiSet4NER")
# Out:
# Downloading:   0%|          | 0.00/5.19k [00:00<?, ?B/s]
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/265k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/70.5k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/32.3k [00:00<?, ?B/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset epi_set downloaded and prepared to /home/wzkariampuzha/.cache/huggingface/datasets/epi_set/EpiSet4NER/1.0.0/7c3b57face34a072ee6d2aec07a32b180ab4b914ea8f42440211e72d8cde6a87. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset = load_dataset("wzkariampuzha/EpiExtract4GARD")

# %%
conllpp = load_dataset("conllpp")

# %%
conllpp['train'][0]['ner_tags']

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 4580
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 1227
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 534
#     })
# })

# %%
data_files = {"train": "train.txt", "val": "val.txt", "test": "test.txt"}
dataset = load_dataset("ncats/EpiSet4NER", data_files=data_files)

# %%
dataset['train'][6]['tokens']
# Out:
# ['CICM',
#  'was',
#  'defined',
#  'as',
#  'a',
#  '≥16',
#  '%',
#  'reduction',
#  'in',
#  'LVEF',
#  'or',
#  '≥10',
#  '%',
#  'reduction',
#  'in',
#  'LVEF',
#  'to',
#  'a',
#  'value',
#  '<',
#  '50',
#  '%',
#  '.']

# %%
for j in range(len(dataset['train'])):
    print('\n---**--',j)
    for i in range(len(dataset['train'][j]['tokens'])):
        print(dataset['train'][j]['tokens'][i])
    

    #for i in range(len(sentence['tokens'])):
    #    print(sentence['ner_tags'][i])
# Out:
#  0
# Background
# Chemotherapy
# -
# induced
# cardiomyopathy
# (
# CICM
# )
# and
# heart
# failure
# are
# major
# complications
# of
# cancer
# therapeutics
# and
# can
# result
# in
# significant
# morbidity
# and
# mortality
# .
#
#  1
# There
# is
# limited
# data
# on
# the
# incidence
# and
# risk
# factors
# of
# CICM
# in
# African
# American
# and
# Afro
# -
# Caribbean
# patients
# .
#
#  2
# Methods
# We
# performed
# a
# retrospective
# chart
# review
# to
# evaluate
# the
# baseline
# characteristics
# that
# may
# predispose
# to
# CICM
# .
#
#  3
# Patients
# were
# African
# American
# and
# Afro
# -
# Caribbean
# ethnicity
# .
#
#  4
# Data
# was
# collected
# between
# 2014
# to
# 2018
# .
#
#  5
# Patients
# had
# transthoracic
# echocardiogram
# (
# TTE
# )
# or
# multigated
# acquisition
# scan
# (
# MUGA
# )
# prior
# to
# cancer
# therapy
# and
# every
# 3
# months
# thereafter
# ,
# until
# the
# end
# of
# the
# regimen
# .
#
#  6
# CICM
# was
# defined
# ...

# %%
dataset['train'][333]['tokens'],dataset['train'][333]['ner_tags']
# Out:
# (['Conclusions',
#   'The',
#   'birth',
#   'prevalence',
#   'of',
#   'CLD',
#   'in',
#   'the',
#   'northern',
#   'Netherlands',
#   'was',
#   '21.1/10,000',
#   'births',
#   '.'],
#  [0, 0, 0, 3, 0, 0, 0, 0, 0, 1, 0, 5, 6, 0])

# %%
dataset['train'][333]
# Out:
# {'id': '333',
#  'tokens': ['Conclusions',
#   'The',
#   'birth',
#   'prevalence',
#   'of',
#   'CLD',
#   'in',
#   'the',
#   'northern',
#   'Netherlands',
#   'was',
#   '21.1/10,000',
#   'births',
#   '.'],
#  'ner_tags': [0, 0, 0, 3, 0, 0, 0, 0, 0, 1, 0, 5, 6, 0]}
