# %% [markdown]
# # Goals:
# Filter the Orphanet complete file to only include:
#  - Rows with >=1 stat AND 1 or less GARD IDs

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Orphanet-Comparison-FINAL.csv')
df
# Out:
#       OrphaCode                                       Disease Name  \
# 0        166024      Multiple epiphyseal dysplasia, Al-Gazali type
# 1        166024      Multiple epiphyseal dysplasia, Al-Gazali type
# 2        166032  Multiple epiphyseal dysplasia, with miniepiphyses
# 3            61                                 Alpha-mannosidosis
# 4            61                                 Alpha-mannosidosis
# ...         ...                                                ...
# 6377      99812                                      LIG4 syndrome
# 6378      99806                            Oculootodental syndrome
# 6379      99807                                 PEHO-like syndrome
# 6380      99792          Dentin dysplasia-sclerotic bones syndrome
# 6381      99776                                   Mosaic trisomy 9
#
#            Orpha Epi Type  Orpha Epi Class  Orpha Epi Rate  Orpha Loc  \
# 0        Point prevalence   <1 / 1 000 000            0.00  Worldwide
# ...

# %%
#converts string sets or lists into a python list
def str2list(string,isRate):
    if isRate:
        if string =='[]':
            #removes all stats with empty lists (list of len 0)
            return np.NaN
        else:
            string = str(string).replace("['","")
            string = string.replace("']","")
            string = str(string).replace("{'","")
            string = string.replace("'}","")
            string = string.strip()
            str_list = string.split("', '")
            return str_list
    else:
        string = str(string).replace("['","")
        string = string.replace("']","")
        string = str(string).replace("{'","")
        string = string.replace("'}","")
        string = string.strip()
        str_list = string.split("', '")
        if len(str_list)>1:
            return np.NaN
        else: 
            return str_list

# %%
for i in range(len(df['GARD Disease ID'])):
    df['GARD Disease ID'][i] = str2list(df['GARD Disease ID'][i],False)
    df['Epi Statistics'][i] = str2list(df['Epi Statistics'][i],True)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['GARD Disease ID']
# Out:
# 0                 [[]]
# 1                 [[]]
# 2                 [[]]
# 3                 [[]]
# 4                 [[]]
#              ...
# 6377              [[]]
# 6378              [[]]
# 6379    [GARD:0010559]
# 6380              [[]]
# 6381    [GARD:0000043]
# Name: GARD Disease ID, Length: 6382, dtype: object

# %%
df
# Out:
#       OrphaCode                                       Disease Name  \
# 0        166024      Multiple epiphyseal dysplasia, Al-Gazali type
# 1        166024      Multiple epiphyseal dysplasia, Al-Gazali type
# 2        166032  Multiple epiphyseal dysplasia, with miniepiphyses
# 3            61                                 Alpha-mannosidosis
# 4            61                                 Alpha-mannosidosis
# ...         ...                                                ...
# 6377      99812                                      LIG4 syndrome
# 6378      99806                            Oculootodental syndrome
# 6379      99807                                 PEHO-like syndrome
# 6380      99792          Dentin dysplasia-sclerotic bones syndrome
# 6381      99776                                   Mosaic trisomy 9
#
#            Orpha Epi Type  Orpha Epi Class  Orpha Epi Rate  Orpha Loc  \
# 0        Point prevalence   <1 / 1 000 000            0.00  Worldwide
# ...

# %%
df.dropna()
# Out:
#       OrphaCode                                   Disease Name  \
# 3            61                             Alpha-mannosidosis
# 5            61                             Alpha-mannosidosis
# 6            61                             Alpha-mannosidosis
# 7            61                             Alpha-mannosidosis
# 8            61                             Alpha-mannosidosis
# ...         ...                                            ...
# 6366      99880         Hyperparathyroidism-jaw tumor syndrome
# 6367      99885  Isolated permanent neonatal diabetes mellitus
# 6368      99885  Isolated permanent neonatal diabetes mellitus
# 6369      99885  Isolated permanent neonatal diabetes mellitus
# 6374      99853                           Ovarioleukodystrophy
#
#            Orpha Epi Type  Orpha Epi Class  Orpha Epi Rate       Orpha Loc  \
# 3     Prevalence at birth   <1 / 1 000 000            0.09       Australia
# ...

# %%
df.dropna().to_csv('Orphanet-Comparison-FINAL-FILTERED.csv', header = True, index=False, encoding='utf-8')
