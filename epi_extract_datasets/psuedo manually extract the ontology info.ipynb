# %% [markdown]
# ### Goals:
# 1. Extract the BioPortal Ethnicity Ontology
# 2. Process the data
# 3. Extract the SNOMED Ethnic Group Ontology
# 4. Process the data
# 5. Combine the ontologies
# 6. Compare the gold standard labeled data to the combined ontology

# %% [markdown]
# #### BioPortal Ethnicity Ontology
# This ethnicity ontology was downloaded as an \*\.owl file from [BioPortal](https://bioportal.bioontology.org/ontologies/EO/?p=summary) on ~Jan 6, 2022 and as there was errors in how it was saved by BioPortal, it was not able to be opened by [OwlReady2](https://pypi.org/project/Owlready2/) so I copied the raw text from the \*\.owl file to a \*\.txt file and processed it here.

# %%
import re
with open("ethnicity ontology in .txt", "r") as f:
    raw_ontology = f.read()
f.close()

# %%
#replace this error
raw_ontology = re.sub("Born_in_Democratic_People&apos;","",raw_ontology)
#all of the ethnicities are between these two character sets described by this regular expression
search_pattern = re.compile(r'"#.+"|#.+<')
raw_ontology_list = search_pattern.findall(raw_ontology)

# %%
len(raw_ontology_list)
# Out:
# 5324

# %%
#This is to remove the identifying character sets
replace_pattern = re.compile(r'"#|<|#|"')

#this time we only want lowercase ethnicity/nationality data and strings less than 50 characters
raw_ontology_list = [replace_pattern.sub("",ont).lower() for ont in raw_ontology_list if len(ont)<50]

# %%
raw_ontology_list[:50]
# Out:
# ['africa',
#  'main_language_spoken',
#  'asia',
#  'main_language_spoken',
#  'australaisa',
#  'main_language_spoken',
#  'europe',
#  'main_language_spoken',
#  'first_language_not_english',
#  'main_language_spoken',
#  'language_spoken_nos',
#  'main_language_spoken',
#  'main_language_spoken',
#  'main_language_spoken',
#  'language',
#  'north_america',
#  'main_language_spoken',
#  'south_america',
#  'main_language_spoken',
#  'main_language_spoken',
#  'born_in_france',
#  'born_in_france',
#  'european_country_of_birth',
#  'hassnomedcode',
#  'born_in_france',
#  'hasctv3code',
#  'born_in_france',
#  'reads_german',
#  'reads_german',
#  'european_languages',
#  'hasread2code',
#  'reads_german',
#  'born_in_hungary',
#  'born_in_hungary',
#  'european_country_of_birth',
#  'hassnomedcode',
#  'born_in_hungary',
#  'hasctv3code',
#  'born_in_hungary',
#  'born_in_brunei',
#  'born_in_brunei',
#  'asian_country_of_birth',
#  'hassnomedcode',
#  'born_in_brunei',
#  'hasctv3code',
#  'born_in_brunei',
#  'kinyarwanda',
#  'kinyarwanda',
#  'africa',
#  'hasread2code']

# %% [markdown]
# As you can see there are a lot of things that we need to remove/replace, so will process them into a dictionary with counts because many errata are repeated often so they will likely show up in a frequency ordered list.

# %%
len(raw_ontology_list)
# Out:
# 5322

# %%
raw_ontology_dict = {}
for ont in raw_ontology_list:
    if r"_"in ont:
        ont = re.sub(r'_',r' ',ont)
    if ont in raw_ontology_dict.keys():
        raw_ontology_dict[ont]+=1
    else:
        raw_ontology_dict[ont]=0

# %%
from collections import OrderedDict
def top_counts(dictionary,num_hits=100,head = True):
    return OrderedDict(sorted(dictionary.items(), key=lambda x: x[1], reverse=head)[:num_hits])

# %%
top_entries = top_counts(raw_ontology_dict)

# %%
top_entries
# Out:
# OrderedDict([('hassnomedcode', 634),
#              ('hasctv3code', 627),
#              ('hasread2code', 294),
#              ('asia', 68),
#              ('asian country of birth', 59),
#              ('african country of birth', 53),
#              ('european country of birth', 52),
#              ('europe', 51),
#              ('asian nationality', 51),
#              ('european nationality', 43),
#              ('the americas', 42),
#              ('african nationality', 42),
#              ('australasia', 34),
#              ('africa', 31),
#              ('american country of birth', 30),
#              ('asian languages', 20),
#              ('european languages', 16),
#              ('atlantic country of birth', 15),
#              ('pacific country of birth', 13),
#              ('country of birth', 11),
#              ('main language spoken', 10),
#              ('nationality', 10),
#              ('asian/asian asian british', 10),
#              ('australaisa', 9),
#              ('other black black asian origin', 9),
#              ('ethnic group', 9),
#              ('white and black', 8),
#              ('black african carribean black british', 8),
#              ('other black', 8),
#              ('white', 8),
#              ('language read', 7),
#              ('other mixed', 7),
#              ('mixed/mixed multiple ethnic groups', 7),
#              ('north america', 6),
#              ('black north african iranian arab', 6),
#              ('african', 6),
#              ('black east afric asia indo caribb', 6),
#              ('carribean', 6),
#              ('ethnicity unspecified', 6),
#              ('hispanic', 6),
#              ('shona', 6),
#              ('urdu', 6),
#              ('wi guyana', 6),
#              ('other white', 6),
#              ('british or mixed british', 6),
#              ('language', 5),
#              ('new zealand ethnic groups', 5),
#              ('african languages', 5),
#              ('english wesh scottish northern irish british', 5),
#              ('arab', 5),
#              ('australasian country of birth', 5),
#              ('black african', 5),
#              ('black east african asian', 5),
#              ('english nationality', 5),
#              ('interpreter requirement', 5),
#              ('n african arab iranian', 5),
#              ('other ethnic asian white origin', 5),
#              ('other ethnic group', 5),
#              ('other ethnic other mixed origin', 5),
#              ('south america', 4),
#              ('luganda', 4),
#              ('reads somali', 4),
#              ('tajik', 4),
#              ('hindi', 4),
#              ('white scottish', 4),
#              ('brawa', 4),
#              ('ndebele', 4),
#              ('wolof', 4),
#              ('afar', 4),
#              ('afrikaans', 4),
#              ('akan', 4),
#              ('albanian', 4),
#              ('amharic', 4),
#              ('arabic', 4),
#              ('armenian', 4),
#              ('asian origin', 4),
#              ('assamese', 4),
#              ('aymara', 4),
#              ('azerbaijani', 4),
#              ('bangladeshi nationality', 4),
#              ('basque', 4),
#              ('belarusian', 4),
#              ('bengali', 4),
#              ('black british', 4),
#              ('black carribean', 4),
#              ('black indian sub-continent', 4),
#              ('black indo- carribean', 4),
#              ('black other african country', 4),
#              ('black other mixed', 4),
#              ('black other non-mixed', 4),
#              ('british ethnic minority specified', 4),
#              ('british ethnic minority unspecified', 4),
#              ('bulgarian', 4),
#              ('burmese', 4),
#              ('cantonese', 4),
#              ('catalan', 4),
#              ('central khmer', 4),
#              ('chinese', 4),
#              ('corsican', 4),
#              ('croatian', 4)])

# %%
#set will do automatic duplicate filtering
final_ontology = set()
for ont in raw_ontology_dict.keys():
    add = True
    if ont in {"hassnomedcode","hasctv3code","hasread2code","country of birth","nationality","ethnic group","or","no"}:
        add=False
    for subword in ["language","read"]:
        if subword in ont:
            add=False
            break
    if add:
        for remove_subword in ["asian/asian","mixed/mixed",r"^or "]:
            if remove_subword in ont:
                ont = re.sub(remove_subword,"",ont).strip()
                final_ontology.add(ont)
            else:
                final_ontology.add(ont)
        for subword in ["ethnicity","nationality","origin","born in","the","other","country of birth"]:
            if subword in ont:
                extra_ont = re.sub(subword,"",ont).strip()
                final_ontology.add(extra_ont)

# %%
final_ontology
# Out:
# {'',
#  'abkhazian',
#  'abyssinians',
#  'admiralty islanders',
#  'afar',
#  'afghanistan',
#  'africa',
#  'african',
#  'african american',
#  'african country',
#  'african country of birth',
#  'african nationality',
#  'afrikaans',
#  'ainu',
#  'akan',
#  'alacaluf',
#  'albania',
#  'albanian',
#  'albanian nationality',
#  'aleuts',
#  'algeria',
#  'american',
#  'american country of birth',
#  'american indian',
#  'americas',
#  'amharic',
#  'andamanese',
#  'andorra',
#  'angola',
#  'antigua and barbuda',
#  'apache',
#  'arab',
#  'arabic',
#  'aragonese',
#  'argentina',
#  'armenia',
#  'armenian',
#  'armenian nationality',
#  'asia',
#  'asian',
#  'asian british',
#  'asian country of birth',
#  'asian nationality',
#  'asian origin',
#  'assamese',
#  'atacamenos',
#  'athabascans',
#  'atlantic',
#  'atlantic country of birth',
#  'australaisa',
#  'australasia',
#  'australasian',
#  'australasian country of birth',
#  'australia',
#  'australian abe',
#  'australian aborigine',
#  'austria',
#  'austrian',
#  'aymara',
#  'aymara nationality',
#  'azerbaijan',
#  'azerbaijani',
#  'aztec',
#  'badagas',
#  'bahamas',
#  'bahrain',
#  'baltic estonian latvian lithuanian',
#  'bamun',
#  'bangladesh',
#  'bangladeshi',
#  'bangladeshi nationality',
#  'bantu',
#  'barbados',
#  'barundi',
#  'bashkir',
#  'basque',
#  'basques',
#  'batusi',
#  'belarusian',
#  'belgian',
#  'belgium',
#  'belize',
#  'belorussia',
#  'bengali',
#  'benin',
#  'bhuatanese',
#  'bhutan',
#  'bihari',
#  'bislama',
#  'black',
#  'black  african country',
#  'black  mixed',
#  'black  non-mixed',
#  'black african',
#  'black african and white',
#  'black african carribean black british',
#  'black and chinese',
#  'black arab',
#  'black black',
#  'black black asian origin',
#  'black black or',
#  'black black other',
#  'black black white origin',
#  'black british',
#  'black caribbean and white',
#  'black carribean',
#  'black east afric asia indo caribb',
#  'black east african asian',
#  'black indian sub-continent',
#  'black indo- carribean',
#  'black iranian',
#  'black jews',
#  'black n african arab iranian',
#  'black north african',
#  'black north african iranian arab',
#  'black or african country',
#  'black or mixed',
#  'black or non-mixed',
#  'black other african country',
#  'black other mixed',
#  'black other non-mixed',
#  'blackfeet',
#  'bloods',
#  'bogobos',
#  'bolivia',
#  'born in  nerlands',
#  'born in afghanistan',
#  'born in albania',
#  'born in algeria',
#  'born in andorra',
#  'born in angola',
#  'born in antigua and barbuda',
#  'born in argentina',
#  'born in armenia',
#  'born in australia',
#  'born in austria',
#  'born in azerbaijan',
#  'born in bahamas',
#  'born in bahrain',
#  'born in bangladesh',
#  'born in barbados',
#  'born in belgium',
#  'born in belize',
#  'born in belorussia',
#  'born in benin',
#  'born in bhutan',
#  'born in bolivia',
#  'born in bosnia herzegovnia',
#  'born in botswana',
#  'born in brazil',
#  'born in british guyana',
#  'born in brunei',
#  'born in bulgaria',
#  'born in burkina faso',
#  'born in burma',
#  'born in burundi',
#  'born in cambodia',
#  'born in cameroon',
#  'born in canada',
#  'born in cape verde islands',
#  'born in central african republic',
#  'born in chad',
#  'born in chechnya',
#  'born in chile',
#  'born in china',
#  'born in columbia',
#  'born in comoros islands',
#  'born in congo',
#  'born in costa rica',
#  'born in croatia',
#  'born in cuba',
#  'born in cyprus',
#  'born in czech republic',
#  'born in democratic peoples republic of korea',
#  'born in denmark',
#  'born in djibouti',
#  'born in dominican republic',
#  'born in east timor',
#  'born in ecuador',
#  'born in egypt',
#  'born in el salvador',
#  'born in england',
#  'born in equatorial guinea',
#  'born in estonia',
#  'born in ethiopia',
#  'born in fiji',
#  'born in finland',
#  'born in france',
#  'born in gabon',
#  'born in gambia',
#  'born in georgia',
#  'born in germany',
#  'born in ghana',
#  'born in greece',
#  'born in grenada',
#  'born in guatemala',
#  'born in guinea bissau',
#  'born in guinea republic',
#  'born in guyana',
#  'born in haiti',
#  'born in honduras',
#  'born in hong kong',
#  'born in hungary',
#  'born in iceland',
#  'born in india',
#  'born in indonesia',
#  'born in iran',
#  'born in iraq',
#  'born in ireland',
#  'born in israel',
#  'born in italy',
#  'born in ivory coast',
#  'born in jamaica',
#  'born in japan',
#  'born in jordan',
#  'born in kazakhstan',
#  'born in kenya',
#  'born in kiribati',
#  'born in kosovo',
#  'born in kuwait',
#  'born in kyrgyzstan',
#  'born in laos',
#  'born in latvia',
#  'born in lebanon',
#  'born in lesotho',
#  'born in liberia',
#  'born in libya',
#  'born in liechenstein',
#  'born in lithuania',
#  'born in luxembourg',
#  'born in madagascar',
#  'born in malawi',
#  'born in malaysia',
#  'born in maldives',
#  'born in mali',
#  'born in malta',
#  'born in mauritania',
#  'born in mauritius',
#  'born in mexico',
#  'born in moldavia',
#  'born in monaco',
#  'born in mongolia',
#  'born in morocco',
#  'born in mozambique',
#  'born in namibia',
#  'born in nauru',
#  'born in nepal',
#  'born in new zealand',
#  'born in nicaragua',
#  'born in niger',
#  'born in nigeria',
#  'born in norrn ireland',
#  'born in north korea',
#  'born in northern ireland',
#  'born in norway',
#  'born in oman',
#  'born in pakistan',
#  'born in palestine',
#  'born in panama',
#  'born in papua new guinea',
#  'born in paraguay',
#  'born in peru',
#  'born in phillipines',
#  'born in poland',
#  'born in portugal',
#  'born in puerto rico',
#  'born in qatar',
#  'born in republic of ireland',
#  'born in republic of korea',
#  'born in romania',
#  'born in russia',
#  'born in rwanda',
#  'born in san marino',
#  'born in sao tome and principe',
#  'born in saudi arabia',
#  'born in scotland',
#  'born in senegal',
#  'born in seychelles',
#  'born in sierra leone',
#  'born in singapore',
#  'born in slovakia',
#  'born in slovenia',
#  'born in solomon islands',
#  'born in somalia',
#  'born in south africa',
#  'born in south korea',
#  'born in spain',
#  'born in sri lanka',
#  'born in st. kitts and nevis',
#  'born in st. lucia',
#  'born in st. vincent',
#  'born in sudan',
#  'born in suriname',
#  'born in swaziland',
#  'born in sweden',
#  'born in switzerland',
#  'born in syria',
#  'born in taiwan',
#  'born in tajikstan',
#  'born in tanzania',
#  'born in thailand',
#  'born in the netherlands',
#  'born in togo',
#  'born in tonga',
#  'born in trinidad and tobago',
#  'born in tunisia',
#  'born in turkey',
#  'born in turkmenistan',
#  'born in tuvala',
#  'born in uganda',
#  'born in ukraine',
#  'born in united arab erimates',
#  'born in uruguay',
#  'born in usa',
#  'born in uzbekistan',
#  'born in vanuatu',
#  'born in vatican city',
#  'born in venezuela',
#  'born in vietnam',
#  'born in wales',
#  'born in western samoa',
#  'born in yemen',
#  'born in yugoslavia',
#  'born in zaire',
#  'born in zambia',
#  'born in zimbabwe',
#  'bororo',
#  'bosnia herzegovnia',
#  'bosnian',
#  'botswana',
#  'brawa',
#  'brazil',
#  'brazilian indians',
#  'breton',
#  'british ethnic minority specified',
#  'british ethnic minority unspecified',
#  'british guyana',
#  'british or mixed british',
#  'brunei',
#  'bruneians',
#  'bulgaria',
#  'bulgarian',
#  'bulgarians',
#  'buriats',
#  'burkina faso',
#  'burma',
#  'burmese',
#  'burundi',
#  'bushmen',
#  'caingang',
#  'cambodia',
#  'cameroon',
#  'canada',
#  'cantonese',
#  'cape verde islands',
#  'caroline islanders',
#  'carribean',
#  'catalan',
#  'central african republic',
#  'central khmer',
#  'chad',
#  'chechnya',
#  'chenchu',
#  'chile',
#  'china',
#  'chinese',
#  'chinese and white',
#  'chinese nationality',
#  'chippewa',
#  'choco',
#  'chuang',
#  'columbia',
#  'commonwealth russian independent states',
#  'comoros islands',
#  'congo',
#  'congolese',
#  'cook island maoris',
#  'cornish',
#  'corsican',
#  'costa rica',
#  'coushatta',
#  'croatia',
#  'croatian',
#  'croatian nationality',
#  'cuba',
#  'cuna',
#  'cypriot',
#  'cyprus',
#  'czech',
#  'czech republic',
#  'czechs',
#  'danes',
#  'danish',
#  'dari',
#  'democratic peoples republic of korea',
#  'denmark',
#  'dieguenos',
#  'djibouti',
#  'dominican republic',
#  'dutch',
#  'dutch nationality',
#  'dyaks',
#  'east africa asian indo carib',
#  'east timor',
#  'easter islanders',
#  'ecuador',
#  'egypt',
#  'egyptian',
#  'el salvador',
#  'ellice islanders',
#  'england',
#  'english',
#  'english nationality',
#  'english wesh scottish norrn irish british',
#  'english wesh scottish northern irish british',
#  'equatorial guinea',
#  'eskimo',
#  'esperanto',
#  'estonia',
#  'estonian',
#  'estonians',
#  'ethiopia',
#  'ethnic  mixed origin',
#  'ethnic asian white origin',
#  'ethnic group',
#  'ethnic mixed white origin',
#  'ethnicity unspecified',
#  'ethopian',
#  'europe',
#  'european',
#  'european country of birth',
#  'european nationality',
#  'european origin',
#  'ewe',
#  'far eastern',
#  'far eastern origin',
#  'faroese',
#  'farsi',
#  'fiji',
#  'fijian',
#  'fijian nationality',
#  'filipino',
#  'filipino nationality',
#  'finland',
#  'finnish',
#  'finns',
#  'flemish',
#  'france',
#  'french',
#  'french creole',
#  'french nationality',
#  'frisian',
#  'fulani',
#  'gabon',
#  'gaelic',
#  'galician',
#  'gambia',
#  'gambians',
#  'georgia',
#  'georgian',
#  'georgians',
#  'german',
#  'germans',
#  'germany',
#  'ghana',
#  'ghanaians',
#  'ghashgai',
#  'gilbertese',
#  'greece',
#  'greek',
#  'greek cypriot',
#  'greek greek cypriot nmo',
#  'greek nationality',
#  'grenada',
#  'guamians',
#  'guarani',
#  'guatemala',
#  'guinea bissau',
#  'guinea republic',
#  'gujarati',
#  'guyana',
#  'gypsy or irish traveller',
#  'gypsy romany',
#  'haiti',
#  'hakka',
#  'hausa',
#  'hawaiians',
#  'hebrew',
#  'hindi',
#  'hindko',
#  'hispanic',
#  'hispanic black',
#  'hispanic colour unknown',
#  'hispanic white',
#  'hobe',
#  'honduras',
#  'hong kong',
#  'hottentot',
#  'huasteco',
#  'huichol',
#  'hungarian',
#  'hungarians',
#  'hungary',
#  'hututu',
#  'iba',
#  'iban',
#  'ibo',
#  'iceland',
#  'icelanders',
#  'icelandic',
#  'igbo',
#  'inca',
#  'india',
#  'indian',
#  'indian or british indian',
#  'indian subcontinent',
#  'indonesia',
#  'indonesian',
#  'indonesians',
#  'information content entity',
#  'interlingua',
#  'interpreter requirement',
#  'inukitut',
#  'inupiaq',
#  'iran',
#  'iranian',
#  'iraq',
#  'iraqi',
#  'ireland',
#  'irish',
#  'irish lang',
#  'irish nationality',
#  'irish nmo',
#  'irish traveller',
#  'irula',
#  'israel',
#  'israeli',
#  'italian',
#  'italian nationality',
#  'italy',
#  'ivory coast',
#  'jamaica',
#  'japan',
#  'japanese',
#  'japanese nationality',
#  'javanese',
#  'jonkha',
#  'jordan',
#  'kalaallisut',
#  'kanarese',
#  'kannada',
#  'kapingas',
#  'kashmiri',
#  'kashmiri nationality',
#  'kazakh',
#  'kazakhstan',
#  'kenya',
#  'kenyans',
#  'kikuyu',
#  'kinyarwanda',
#  'kirghiz',
#  'kirgiz',
#  'kiribati',
#  'konkani',
#  'korean',
#  'koreans',
#  'kosovan',
#  'kosovo',
#  'kurdish',
#  'kurdish nationality',
#  'kutchi',
#  'kuwait',
#  'kwakiutl',
#  'kyrgyzstan',
#  'labradors',
#  'lacandon',
#  'lao',
#  'laos',
#  'lapps',
#  'latin american',
#  'latvia',
#  'latvian',
#  'lebanon',
#  'lesotho',
#  'liberia',
#  'liberians',
#  'libya',
#  'liechenstein',
#  'lingala',
#  'lithuania',
#  'lithuanian',
#  'luganda',
#  'luo',
#  'luxembourg',
#  'macedonian',
#  'madagascans',
#  'madagascar',
#  'malagasy',
#  'malawi',
#  'malay',
#  'malayalam',
#  'malays',
#  'malaysia',
#  'malaysian',
#  'maldives',
#  'mali',
#  'malta',
#  'maltese',
#  'mandarin',
#  'maori',
#  'maoris',
#  'mapuche',
#  'marathas',
#  'marathi',
#  'marshallese',
#  'mauritania',
#  'mauritian seychellois maldivian st helena',
#  'mauritius',
#  'maya',
#  'melanesian',
#  'melanuans',
#  'mexican indians',
#  'mexico',
#  'micronesians',
#  'middle east',
#  'middle eastern',
#  'middle eastern origin',
#  'mirpuri',
#  'mixed',
#  'mixed asian',
#  'mixed/mixed multiple ethnic groups',
#  'moldavia',
#  'moldovian',
#  'monaco',
#  'mongolia',
#  'mongolian',
#  'moroccan',
#  'morocco',
#  'mozambiquans',
#  'mozambique',
#  'msutu',
#  'multiple ethnic groups',
#  'n african arab iranian',
#  'naiars',
#  'namibia',
#  'nauru',
#  'nauruan',
#  'navaho',
#  'ndebele',
#  'nepal',
#  'nepali',
#  'new britons',
#  'new caledonians',
#  'new hebrideans',
#  'new zealand',
#  'new zealand ethnic groups',
#  'new zealand european',
#  'new zealand maori',
#  'nez perce',
#  'nicaragua',
#  'niger',
#  'nigeria',
#  'nigerian',
#  'nigerians',
#  'niuean',
#  'norrn irish',
#  'north african',
#  'north african arab',
#  'north america',
#  'north american',
#  'north american nationality',
#  'north american origin',
#  'north korea',
#  'northern ireland',
#  'northern irish',
#  'norway',
#  'norwegian',
#  'norwegians',
#  'occitan',
#  'oman',
#  'onge',
#  'or',
#  'or african country',
#  'or asian',
#  'or black',
#  'or black black asian origin',
#  'or black black white origin',
#  'or ethnic asian white origin',
#  'or ethnic group',
#  'or ethnic mixed white origin',
#  'or ethnic or mixed origin',
#  'or european',
#  'or mixed',
#  'or white',
#  'or white british ethnic group',
#  'or white ethnic group',
#  'oraons',
#  'oriental',
#  'oriental jews',
#  'oriya',
#  'oromo',
#  'other',
#  'other african country',
#  'other asian',
#  'other black',
#  'other black black asian',
#  'other black black asian origin',
#  'other black black white',
#  'other black black white origin',
#  'other ethnic asian white',
#  'other ethnic asian white origin',
#  'other ethnic group',
#  'other ethnic mixed white',
#  'other ethnic mixed white origin',
#  'other ethnic other mixed',
#  'other ethnic other mixed origin',
#  'other european',
#  'other mixed',
#  'other white',
#  'other white british ethnic group',
#  'other white ethnic group',
#  'pacific',
#  'pacific country of birth',
#  'paez',
#  'pakistan',
#  'pakistani',
#  'pakistani nationality',
#  'palauans',
#  'palestine',
#  'panama',
#  'papua new guinea',
#  'papuans',
#  'paraguay',
#  'pashto',
#  'patois',
#  'pehuenches',
#  'persian',
#  'peru',
#  'phillipines',
#  'poland',
#  'polish',
#  'polish nationality',
#  'polynesians',
#  'portugal',
#  'portugese',
#  'portugese nationality',
#  'pueblo',
#  'puerto rico',
#  'punjabi',
#  'punjabi nationality',
#  'pygmies',
#  'qatar',
#  'quechua',
#  'quechua nationality',
#  'republic of ireland',
#  'republic of korea',
#  'republics former yugoslavia',
#  'romania',
#  'romanian',
#  'romanians',
#  'romansh',
#  'ruanda',
#  'rundi',
#  'russia',
#  'russian',
#  'russians',
#  'rwanda',
#  'saipanese',
#  'samoan',
#  'samoan nationality',
#  'san marino',
#  'sango',
#  'sao tome and principe',
#  'saudi arabia',
#  'scotland',
#  'scottish',
#  'seminole',
#  'senegal',
#  'senegalese',
#  'senoi',
#  'serbian',
#  'serbian nationality',
#  'serbo croatian',
#  'seychelles',
#  'shona',
#  'shoshone',
#  'siamese',
#  'sierra leone',
#  'sindhi',
#  'singapore',
#  'sinhala',
#  'sinhalese',
#  'sinhalese nationality',
#  'slovak',
#  'slovakia',
#  'slovaks',
#  'slovenia',
#  'slovenian',
#  'solomon islanders',
#  'solomon islands',
#  'somali',
#  'somali nationality',
#  'somalia',
#  'somalis',
#  'sourn sotho',
#  'south africa',
#  'south america',
#  'south american',
#  'south american nationality',
#  'south american origin',
#  'south and central american',
#  'south asian aborigonie',
#  'south korea',
#  'southern sotho',
#  'spain',
#  'spaniards',
#  'spanish',
#  'sri lanka',
#  'sri lankan',
#  'st. kitts and nevis',
#  'st. lucia',
#  'st. vincent',
#  'sudan',
#  'sudanese',
#  'sudanese nationality',
#  'suriname',
#  'swahili',
#  'swati',
#  'swaziland',
#  'sweden',
#  'swedes',
#  'swedish',
#  'swiss',
#  'switzerland',
#  'sylheti',
#  'sylhety',
#  'syria',
#  'syrians',
#  'tagalog',
#  'taiwan',
#  'tajik',
#  'tajikstan',
#  'tamil',
#  'tamil nationality',
#  'tanganyikans',
#  'tanzania',
#  'tatar',
#  'tatars',
#  'telugu',
#  'tetum',
#  'thai',
#  'thailand',
#  'thais',
#  'the americas',
#  'the netherlands',
#  'tiawenese',
#  'tibetan',
#  'tigrinya',
#  'toba',
#  'todas',
#  'togo',
#  'tokelauan',
#  'tonga',
#  'tongan',
#  'tongan nationality',
#  'trinidad and tobago',
#  'tristan da cunhans',
#  'trukese',
#  'tsonga',
#  'tswana',
#  'tunisia',
#  'turkey',
#  'turkish',
#  'turkish cypriot',
#  'turkish nationality',
#  'turkish turkish cypriot nmo',
#  'turkmen',
#  'turkmenistan',
#  'tutsi',
#  'tuvala',
#  'twi',
#  'uganda',
#  'ugandans',
#  'uighur',
#  'ukraine',
#  'ukranian',
#  'ulster scots',
#  'united arab erimates',
#  'unknown',
#  'unknown country of birth',
#  'unspecified',
#  'urdu',
#  'uruguay',
#  'usa',
#  'utes',
#  'uzbek',
#  'uzbekistan',
#  'vanuatu',
#  'vatican city',
#  'venezuela',
#  'venezuelan indians',
#  'vietnam',
#  'vietnamese',
#  'wales',
#  'welsh',
#  'welsh nationality',
#  'west africans',
#  'west indian',
#  'west indian origin',
#  'western samoa',
#  'white',
#  'white and asian',
#  'white and black',
#  'white and black african',
#  'white and black carribean',
#  'white british',
#  'white british ethnic group',
#  'white ethnic group',
#  'white irish',
#  'white scottish',
#  'wi guyana',
#  'wolof',
#  'xavante',
#  'xhosa',
#  'xosa',
#  'yanomama',
#  'yapese',
#  'yemen',
#  'yes',
#  'yiddish',
#  'yoruba',
#  'yugoslavia',
#  'zaire',
#  'zambia',
#  'zimbabwe',
#  'zulu',
#  'zulu nationality'}

# %%
len(final_ontology)
# Out:
# 937

# %%
#Save
import json
with open('BioPortal ethnicities.json', 'w') as f:
    json.dump({'ethnicities':list(final_ontology)}, f)
f.close()

# %% [markdown]
# #### SNOMED Ethnicity Ontology
# This ethnicity ontology was downloaded as an \*\.csv file from [BioPortal](https://bioportal.bioontology.org/ontologies/SNOMED-Ethnic-Group/?p=summary) on March 7, 2022.

# %%
import pandas as pd
df = pd.read_csv('SNOMED-Ethnic-Group.csv')
df
# Out:
#                                               Class ID  \
# 0    http://purl.bioontology.org/ontology/SNOMED-Et...
# 1    http://purl.bioontology.org/ontology/SNOMED-Et...
# 2    http://purl.bioontology.org/ontology/SNOMED-Et...
# 3    http://purl.bioontology.org/ontology/SNOMED-Et...
# 4    http://purl.bioontology.org/ontology/SNOMED-Et...
# ..                                                 ...
# 256  http://purl.bioontology.org/ontology/SNOMED-Et...
# 257  http://purl.bioontology.org/ontology/SNOMED-Et...
# 258  http://purl.bioontology.org/ontology/SNOMED-Et...
# 259  http://purl.bioontology.org/ontology/SNOMED-Et...
# 260  http://purl.bioontology.org/ontology/SNOMED-Et...
#
#               Preferred Label  Synonyms  Definitions  Obsolete  CUI  \
# 0    North African Arab (NMO)       NaN          NaN     False  NaN
# 1           Solomon Islanders       NaN          NaN     False  NaN
# 2                      Naiars       NaN          NaN     False  NaN
# 3                      Czechs       NaN          NaN     False  NaN
# 4                   Egyptians       NaN          NaN     False  NaN
# ..                        ...       ...          ...       ...  ...
# 256         Other Asian (NMO)       NaN          NaN     False  NaN
# 257       Admiralty Islanders       NaN          NaN     False  NaN
# 258                     Senoy       NaN          NaN     False  NaN
# 259               Athabascans       NaN          NaN     False  NaN
# 260             Turkish (NMO)       NaN          NaN     False  NaN
#
#      Semantic Types                                            Parents  \
# 0               NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
# 1               NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
# 2               NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
# 3               NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
# 4               NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
# ..              ...                                                ...
# 256             NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
# 257             NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
# 258             NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
# 259             NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
# 260             NaN  http://purl.bioontology.org/ontology/SNOMED-Et...
#
#      CONCEPTSTATUS CTV3ID  ... SNOMEDID                                 SY  \
# 0                0  XM1SB  ...  F-0085C                                NaN
# 1                0  XUEyV  ...  S-65230                                NaN
# 2                0  XULbS  ...  S-66060                                NaN
# 3                0  XUB0u  ...  S-61070                                NaN
# 4                0  XU8qN  ...  S-61100                                NaN
# ..             ...    ...  ...      ...                                ...
# 256              0  9SA8.  ...  F-00198  Other Asian (NMO) (Id: 154190006)
# 257              0  XUARe  ...  S-65010                                NaN
# 258              0  XUFOW  ...  S-64170                                NaN
# 259              0  XUCuT  ...  S-63050                                NaN
# 260              0  XM1SH  ...  F-00862                                NaN
#
#                                   SYNONYM FN SYNONYM IS SYNONYM MTH_FN  \
# 0    North African Arab (NMO) (ethnic group)        NaN            NaN
# 1           Solomon Islanders (ethnic group)        NaN            NaN
# 2                      Naiars (ethnic group)        NaN            NaN
# 3                      Czechs (ethnic group)        NaN            NaN
# 4                   Egyptians (ethnic group)        NaN            NaN
# ..                                       ...        ...            ...
# 256         Other Asian (NMO) (ethnic group)        NaN            NaN
# 257       Admiralty Islanders (ethnic group)        NaN            NaN
# 258                     Senoy (ethnic group)        NaN            NaN
# 259               Athabascans (ethnic group)        NaN            NaN
# 260             Turkish (NMO) (ethnic group)        NaN            NaN
#
#     SYNONYM MTH_PT SYNONYM OF SYNONYM SY   TUI  UMLS_CUI
# 0              NaN        NaN        NaN  T098  C0554961
# 1              NaN        NaN        NaN  T098  C0337932
# 2              NaN        NaN        NaN  T098  C0337943
# 3              NaN        NaN        NaN  T098  C0337799
# 4              NaN        NaN        NaN  T098  C0337801
# ..             ...        ...        ...   ...       ...
# 256            NaN        NaN        NaN  T098  C0422793
# 257            NaN        NaN        NaN  T098  C0337913
# 258            NaN        NaN        NaN  T098  C0337906
# 259            NaN        NaN        NaN  T098  C0337857
# 260            NaN        NaN        NaN  T098  C0554967
#
# [261 rows x 26 columns]

# %%
df_ethnicities = set(df['Preferred Label'])
df_ethnicities
# Out:
# {'Abyssinians (Amharas)',
#  'Admiralty Islanders',
#  'African American',
#  'Afro-Caribbean',
#  'Afro-Caucasian',
#  'Ainu',
#  'Alacaluf',
#  'Aleuts',
#  'Amerind',
#  'Andamanese',
#  'Apache',
#  'Arabs',
#  'Armenians',
#  'Asian - ethnic group',
#  'Atacamenos',
#  'Athabascans',
#  'Australian Aborigines',
#  'Austrians',
#  'Aymara',
#  'Aztec',
#  'Badagas',
#  'Bangladeshi',
#  'Bantu',
#  'Barundi',
#  'Basques',
#  'Batutsi',
#  'Belgians',
#  'Bhutanese',
#  'Black - ethnic group',
#  'Black - other African country',
#  'Black - other Asian',
#  'Black - other, mixed',
#  'Black African',
#  'Black African and White',
#  'Black Arab',
#  'Black British',
#  'Black Caribbean',
#  'Black Caribbean and White',
#  'Black Caribbean/W.I./Guyana',
#  'Black East African Asian',
#  'Black East African Asian/Indo-Caribbean',
#  'Black Guyana',
#  'Black Indian sub-continent',
#  'Black Indo-Caribbean',
#  'Black Iranian',
#  'Black Jews',
#  'Black N African/Arab/Iranian',
#  'Black North African',
#  'Black West Indian',
#  'Black, other, non-mixed origin',
#  'Blackfeet',
#  'Bloods',
#  'Bogobos',
#  'Bororo',
#  'Brazilian Indians',
#  'British ethnic minority specified (NMO)',
#  'British ethnic minority unspecified (NMO)',
#  'Bruneians',
#  'Bulgarians',
#  'Buriats',
#  'Bushmen',
#  'Caingang',
#  'Caribbean I./W.I./Guyana (NMO)',
#  'Caribbean Island (NMO)',
#  'Caroline Islanders',
#  'Caucasian',
#  'Chenchu',
#  'Chinese',
#  'Chippewa',
#  'Choco',
#  'Congolese',
#  'Cook Island Maori',
#  'Coushatta',
#  'Cuna',
#  'Czechs',
#  'Danes',
#  'Dieguenos',
#  'Dutch',
#  'Dyaks',
#  'E Afric Asian/Indo-Carib (NMO)',
#  'East African Asian (NMO)',
#  'Easter Islanders',
#  'Egyptians',
#  'Ellice Islanders',
#  'English',
#  'Eskimo',
#  'Estonians',
#  'Ethnic group',
#  'Ethnic groups (1991 census) (UK)',
#  'European',
#  'Ewe',
#  'Fijian',
#  'Filipinos',
#  'Finns',
#  'Flathead',
#  'French',
#  'Fulani',
#  'Gambians',
#  'Georgians',
#  'Germans',
#  'Ghanaians',
#  'Ghashgai',
#  'Gilbertese',
#  'Greek (NMO)',
#  'Greek Cypriot (NMO)',
#  'Greek/Greek Cypriot (NMO)',
#  'Greeks',
#  'Guamians',
#  'Guyana (NMO)',
#  'Gypsies',
#  'Hawaiians',
#  'Hobe',
#  'Hottentot',
#  'Huasteco',
#  'Huichol',
#  'Hungarians',
#  'Hututu',
#  'Ibo',
#  'Icelanders',
#  'Inca',
#  'Indian (East Indian)',
#  'Indian sub-continent (NMO)',
#  'Indians (Hindi-speaking)',
#  'Indo-Caribbean (NMO)',
#  'Indonesians',
#  'Irani',
#  'Iranian (NMO)',
#  'Iraqi',
#  'Irish (NMO)',
#  'Irish traveller',
#  'Irula',
#  'Italians',
#  'Japanese',
#  'Javanese',
#  'Kapingas',
#  'Kenyans',
#  'Kikuyu',
#  'Kirghiz',
#  'Koreans',
#  'Kwakiutl',
#  'Labradors',
#  'Lacandon',
#  'Lapps',
#  'Liberians',
#  'Luo',
#  'Madagascans',
#  'Malayans',
#  'Maori',
#  'Mapuche',
#  'Marathas',
#  'Marshallese',
#  'Maya',
#  'Melanesian',
#  'Melanesians',
#  'Melanuans',
#  'Mexican Indians',
#  'Micronesians',
#  'Mixed ethnic census group',
#  'Mongoloid',
#  'Mozambiquans',
#  'Msutu',
#  'N African Arab/Iranian (NMO)',
#  'Naiars',
#  'Navaho',
#  'New Britons',
#  'New Caledonians',
#  'New Hebrideans',
#  'New Zealand European',
#  'New Zealand Maori',
#  'New Zealand ethnic groups',
#  'Nez PercÃ©',
#  'Nigerians',
#  'Niuean',
#  'North African Arab (NMO)',
#  'Norwegians',
#  'Oceanian',
#  'Onge',
#  'Oraons',
#  'Oriental',
#  'Oriental Jews',
#  'Other African countries (NMO)',
#  'Other Asian (NMO)',
#  'Other Asian ethnic group',
#  'Other Black - Black/Asian orig',
#  'Other Black - Black/White orig',
#  'Other European (NMO)',
#  'Other European in New Zealand',
#  'Other black ethnic group',
#  'Other ethnic non-mixed (NMO)',
#  'Other ethnic, Asian/White origin',
#  'Other ethnic, Black/White origin',
#  'Other ethnic, mixed origin',
#  'Other ethnic, mixed white origin',
#  'Other ethnic, other mixed origin',
#  'Other white British ethnic group',
#  'Paez',
#  'Pakistani',
#  'Pakistani (Urduspeakers)',
#  'Palauans',
#  'Papuans',
#  'Pehuenches',
#  'Poles',
#  'Polynesians',
#  'Portuguese',
#  'Pueblo',
#  'Pygmies',
#  'Quechua',
#  'Race: West indian',
#  'Russians',
#  'Saipanese',
#  'Samoan',
#  'Seminole',
#  'Senegalese',
#  'Senoy',
#  'Serbs',
#  'Shona',
#  'Shoshone',
#  'Siamese',
#  'Slovaks',
#  'Solomon Islanders',
#  'Somalis',
#  'South Asian AND/OR Australian aborigine',
#  'South Asian Aborigine',
#  'South East Asian',
#  'Spaniards',
#  'Sudanese',
#  'Swedes',
#  'Swiss',
#  'Syrians',
#  'Taiwanese',
#  'Tamils',
#  'Tanganyikans',
#  'Tatars',
#  'Thais',
#  'Toba',
#  'Todas',
#  'Tokelauan',
#  'Tongan',
#  'Tristan da Cunhans',
#  'Trukese',
#  'Turkish (NMO)',
#  'Turkish Cypriot (NMO)',
#  'Turkish/Turkish Cypriot (NMO)',
#  'Turks',
#  'Tutsi',
#  'Ugandans',
#  'Utes',
#  'Venezuelan Indians',
#  'Vietnamese',
#  'Welsh',
#  'West Africans',
#  'West Indian (NMO)',
#  'White - ethnic group',
#  'White British',
#  'White Irish',
#  'White Scottish',
#  'Xavante',
#  'Xosa',
#  'Yanomama',
#  'Yapese',
#  'Zulu'}

# %%
snomed_ethnicities = set()
for ethn in df_ethnicities:
    if "(NMO)" in ethn:
        extra_ethn = re.sub("(NMO)","",ethn).strip()
        snomed_ethnicities.add(extra_ethn)
    
    if ' - ethnic group' in ethn:
        extra_ethn = re.sub(' - ethnic group',"",ethn).strip()
        snomed_ethnicities.add(extra_ethn)
        
    if 'N ' in ethn:
        extra_ethn = re.sub('N ',"North ",ethn).strip()
        snomed_ethnicities.add(extra_ethn)
        
    if '-' in ethn:
        extra_ethn = re.sub('-'," ",ethn).strip()
        snomed_ethnicities.add(extra_ethn)

snomed_ethnicities = snomed_ethnicities.union(df_ethnicities)
snomed_ethnicities = {ethn.lower() for ethn in snomed_ethnicities}
len(snomed_ethnicities)
# Out:
# 309

# %%
#Save
with open('SNOMED ethnicities.json', 'w') as f:
    json.dump({'ethnicities':list(snomed_ethnicities)}, f)
f.close()

# %% [markdown]
# #### Combine the Ontologies

# %%
#Re-open ethnicities
import json
with open('BioPortal ethnicities.json', 'r') as f:
    data = json.load(f)
    bioportal_ethnicities = {ethnicity for ethnicity in data['ethnicities']}
f.close()

# %%
#Re-open ethnicities
import json
with open('SNOMED ethnicities.json', 'r') as f:
    data = json.load(f)
    snomed_ethnicities = {ethnicity for ethnicity in data['ethnicities']}
f.close()

# %%
ethnicity_ontologies = bioportal_ethnicities.union(snomed_ethnicities)

# %%
import csv
tokens, labels= [],[]
with open("epi_gold_set.tsv", 'r') as f:
    reader = csv.reader(f, delimiter="\t", quoting=csv.QUOTE_NONE)
    tokens = [row[0] for row in reader if len(row)>1]
    f.seek(0)
    labels = [row[1] for row in reader if len(row)>1]
f.close()

# %%
len(tokens),len(labels)
# Out:
# (159141, 159141)

# %%
ethnicity_phrases = []
for i in range(len(tokens)):
    if labels[i]=='B-ETHN':
        j=1
        while True:
            if labels[i+j]!='I-ETHN':
                break
            else:
                j+=1 
        if j>1:
            phrase = ' '.join(tokens[i:i+j])
        else:
            phrase = tokens[i]
        
        phrase = re.sub(r' - ',r'-',phrase)
        ethnicity_phrases.append(phrase.lower())

# %%
ethnicity_phrases
# Out:
# ['african american',
#  'afro-caribbean',
#  'african american',
#  'afro-caribbean',
#  'african americans',
#  'afro-caribbean',
#  'iranian',
#  'chinese',
#  'chinese',
#  'chinese',
#  'korean',
#  'japanese',
#  'japanese',
#  'japanese',
#  'malaysian orang asli',
#  'hong kong chinese',
#  'arab',
#  'arab',
#  'swedish',
#  'european',
#  'swedish',
#  'black',
#  'mexican',
#  'iranian',
#  'european',
#  'moroccan',
#  'moroccan',
#  'american',
#  'european',
#  'lebanese',
#  'danish',
#  'german',
#  'german',
#  'german',
#  'caucasian',
#  'quebec',
#  'japanese',
#  'japanese',
#  'north american',
#  'north american',
#  'turkish',
#  'arab',
#  'qataris',
#  'arab',
#  'arab',
#  'qataris',
#  'arab',
#  'finnish',
#  'finnish',
#  'qatari',
#  'qatari',
#  'qatari',
#  'qatari',
#  'portuguese',
#  'asian',
#  'iranian',
#  'brazilian',
#  'brazilian',
#  'european',
#  'asian',
#  'chinese',
#  'indian',
#  'indian',
#  'indian',
#  'indian',
#  'indian',
#  'indian',
#  'israeli',
#  'norwegian',
#  'black',
#  'white',
#  'black',
#  'white',
#  'black',
#  'black',
#  'brazilian',
#  'xikrin tribe',
#  'kayapo',
#  'kayapo',
#  'brazilian',
#  'japanese',
#  'brazilian',
#  'french',
#  'chinese',
#  'chinese',
#  'chinese',
#  'africa',
#  'chinese',
#  'malay',
#  'indians',
#  'chinese',
#  'chinese',
#  'chinese',
#  'chinese',
#  'chinese',
#  'north african',
#  'libyan',
#  'japanese',
#  'dutch',
#  'dutch',
#  'european',
#  'caucasians',
#  'asians',
#  'africans',
#  'turkish population',
#  'french',
#  'french',
#  'french',
#  'french-canadian population',
#  'italian',
#  'sicilian',
#  'sicilian',
#  'chinese',
#  'japanese',
#  'japanese',
#  'finnish',
#  'english',
#  'german',
#  'german',
#  'italian',
#  'italian',
#  'pakistani',
#  'white',
#  'white',
#  'black',
#  'chinese',
#  'thai',
#  'chinese',
#  'chinese',
#  'chinese',
#  'chinese',
#  'chinese',
#  'european',
#  'chinese',
#  'burundian',
#  'africa',
#  'africa',
#  'africa',
#  'english',
#  'french',
#  'polish',
#  'polish',
#  'polish',
#  'non-hispanic whites',
#  'africans',
#  'english',
#  'belgian',
#  'chinese',
#  'chinese',
#  'europeans',
#  'chinese',
#  'american',
#  'chilean',
#  'danish',
#  'greenlandic',
#  'faroese',
#  'italian',
#  'greenland',
#  'spanish',
#  'dutch',
#  'dutch',
#  'canadian manitoba mennonite',
#  'dutch',
#  'dutch',
#  'manitoba mennonite',
#  'danish',
#  'danish',
#  'arabs',
#  'arab',
#  'arab',
#  'arabs',
#  'arabs',
#  'nepalese',
#  'nepalese',
#  'korean',
#  'japanese',
#  'japanese',
#  'norwegian',
#  'pakistani',
#  'pakistani',
#  'japanese',
#  'japanese',
#  'english',
#  'portuguese',
#  'brazilian',
#  'american',
#  'japanese',
#  'korean',
#  'korean',
#  'japanese',
#  'japanese',
#  'japanese',
#  'chilean',
#  'mestizos',
#  'german',
#  'italian',
#  'italian',
#  'italian',
#  'australian',
#  'swedish',
#  'iñupiaq',
#  'yupik',
#  'norwegian',
#  'roma',
#  'roma',
#  'roma',
#  'roma',
#  'roma',
#  'roma',
#  'macedonian',
#  'roma',
#  'roma',
#  'roma',
#  'chinese']

# %%
yes = 0
for labeled_ethnicity in ethnicity_phrases:
    if labeled_ethnicity in ethnicity_ontologies:
        yes+=1
    else:
        print(labeled_ethnicity)
print("Total coverage: ",yes/len(ethnicity_phrases))
# Out:
# african americans
# malaysian orang asli
# hong kong chinese
# mexican
# lebanese
# quebec
# qataris
# qataris
# qatari
# qatari
# qatari
# qatari
# brazilian
# brazilian
# brazilian
# xikrin tribe
# kayapo
# kayapo
# brazilian
# brazilian
# indians
# libyan
# caucasians
# asians
# africans
# turkish population
# french-canadian population
# sicilian
# sicilian
# burundian
# non-hispanic whites
# africans
# europeans
# chilean
# greenlandic
# greenland
# canadian manitoba mennonite
# manitoba mennonite
# nepalese
# nepalese
# brazilian
# chilean
# mestizos
# australian
# iñupiaq
# yupik
# roma
# roma
# roma
# roma
# roma
# roma
# roma
# roma
# roma
# Total coverage:  0.7429906542056075
